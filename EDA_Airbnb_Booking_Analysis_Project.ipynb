# %% [markdown]
# <a href="https://colab.research.google.com/github/MagadeviS/Airbnb--EDA/blob/main/EDA_Airbnb_Booking_Analysis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name  - Airbnb Booking Analysis**

# %% [markdown]
# #### **Project Type**    - Exploratory data analysis
# #### **Contribution**    - Individual
# #### **Team Member** - Magadevi S

# %% [markdown]
# # **Project Summary**
#
# Airbnb is an online marketplace that connects people who want to rent out their homes with people looking for accommodations in that locale. In this EDA project, we were provided with a dataset. i.e., Airbnb NYC.  This dataset provides the information on people who want to rent out their homes and people who are looking for accommodations in that locale in New York City.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *Contribution* :
#
# 1. Data pre-processing
#
# 2. Treating Null values
#
# 3. Outliers treatment
#
# 4. Finding a busiest host
#
# 5. Minimum, Maximum and Average price for each neighbourhood group
#
# 6. Total number of listings present in each room type
#
# 7. Maximum price to minimum price of the place in an order
#
# 8. Total number of rooms occupied in each neighbourhood group
#
# 9. Finding the number of days available for  room in a year
#
# 10. Top 10 places based on number of reviews
#
#
# In the first step, we have performed data wrangling over the raw data. The EDA has been analysed based on 6 objects i.e,
# 1. The  Analysis based on host with calculated host listings count
# 2. The Analysis based on price with neighbourhood group
# 3. The Analysis based on order of price
# 4. The Analysis based on room types with neighbourhood group
# 5. The Analysis based on availability of room with neighbourhood group
# 6. The Analysis based on top place with neighbourhood group
#
#
# In  analysis based on host with calculated host listings count, we analysed that the total number of properties owned by different hosts in every neighbourhood group.
# From that, we can conclude that the Sonder(NYC) from Manhattan is the busiest host and having maximum number of properties.
#
# In analysis based on price with neighbourhood group,  we have done analysis on price with different neighbourhood groups,   minimum price for each neighbourhood group, maximum price for each neighbourhood group, mean price for each neighbourhood group. Through this analysis, we concluded that the Manhattan, Brooklyn, Queens has the Maximum price.
#
# In  analysis based on order of price, we have  sorted into  the price ranges from highest price to lowest price. From that, we can find the "Furnished room in Astoria apartment" from Queens , "Luxury 1 bedroom apt. -stunning Manhattan views" from Brooklyn and "1-BR Lincoln Centre" from Manhattan which are the most expensive.
#
# In analysis based on room types with neighbourhood group, total number of different room types has found in each neighbourhood group. From that, we can observe that the neighbourhood groups Brooklyn and Manhattan in which room type of private room and Entire home/apt only mostly occupied.
#
# In Analysis based on availability of room with neighbourhood group, from that  we can observe that which neighbourhood group has most of the days  available in a year. In the analysis we found that the Staten island is the most available in the year.
#
# In  Analysis based on top place with neighbourhood group, the place which has most number of reviews was found  from all the neighbourhood groups. From here we find that the “Room near JFK Queen Bed”  has the most number of reviews.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/MagadeviS/Airbnb--EDA/blob/main/EDA_Airbnb_Booking_Analysis_Project.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# <b> Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. </b>
#
# <b>This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values. </b>
#
# <b> Explore and analyze the data to discover key understandings (not limited to these) such as :
#  * What can we learn about different hosts and areas?
#  * What can we learn from predictions? (ex: locations, prices, reviews, etc)
#  * Which hosts are the busiest and why?
#  * Is there any noticeable difference of traffic among different areas and what could be the reason for it? </b>

# %% [markdown]
# We will perform exploratory data analysis with python to get insight from the data.
#
# ### **We will try to answer the following Questions**
# 1.Which hosts are the busiest and why?
#
# 2.Find the price range in respective neighbourhood(min,max and average price)
#
# 3.Find the price range from highest to lowest order?
#
# 4.How room types occupied by a neighbourhood group?
#
# 5.Find availability of room for each neighbourhood group ?
#
# 6.Find the Top 10 places name based on number of reviews?

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ## **Import Packages**
#
# First Import necessary packages and import the dataset

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# import matplot
from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # ***2. Dataset Loading***

# %% [markdown]
# Now import and display the dataset

# %%
1 # Import Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read csv file
file_path = '/content/drive/MyDrive/Airbnb NYC 2019 (1).csv'
airbnb_df1=pd.read_csv(file_path)

# %% [markdown]
# ### ***2.1 Dataset First View***

# %% [markdown]
# First copy the dataset, so our original dataset remains unchanged

# %%
airbnb_df = airbnb_df1.copy()

# %%
# Dataset First Look (first five rows and last five rows of the dataset)
airbnb_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### ***2.2 Dataset Rows & Columns count***

# %%
# Dataset Rows & Columns count
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# We can find from the above information , there are 16 columns and 48895 rows in the dataset.

# %% [markdown]
# ### ***2.3 Dataset Information***

# %%
# Dataset Info
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# From that, we can observe that there are some missing values and no null values are there in the data set.

# %% [markdown]
# ###  ***2.4 Duplicate Values***

# %%
# Dataset Duplicate Value 
airbnb_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# From that, we can observe that there are no duplicate value in the dataset.

# %% [markdown]
# ### ***2.5 Missing Values/Null Values***

# %%
# Missing Values/Null Values Count
airbnb_df.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# last_review            10052
# reviews_per_month      10052
# host_name                 21
# name                      16
# id                         0
# host_id                    0
# neighbourhood_group        0
# neighbourhood              0
# latitude                   0
# longitude                  0
# dtype: int64

# %%
# Visualizing the missing values
import missingno as msno
msno.bar(airbnb_df)
# Out:
# <Axes: >

# %% [markdown]
# From that above visualization, we can find most of the missing values are present in the last review column and reviews per month column.

# %% [markdown]
# ### ***Things understood from the dataset till now***

# %% [markdown]
# *  There are 16 columns and 48895 rows in the dataset.
#
# *  In the 'reviews_per_month','last_review','host_name','name' columns having some missing values.

# %% [markdown]
# ## ***3. Understanding Your Variables***

# %%
# Dataset Columns
print("Dataset column names:",airbnb_df.columns)
# Out:
# Dataset column names: Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# Now we can get brief description of the dataset such as minimum, maximum, mean, count, standand values and quartile values Q1, Q2, Q3.

# %% [markdown]
# ### ***3.1 Check Unique Values for each variable.***

# %%
# Check Unique Values for each variable.
airbnb_df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ### ***3.2.Data Wrangling***

# %% [markdown]
# ### **Dealing with Missing Values**
#
# To Find the missing value, show the total null values for each column and sort it in descending order

# %%
airbnb_df.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# last_review            10052
# reviews_per_month      10052
# host_name                 21
# name                      16
# id                         0
# host_id                    0
# neighbourhood_group        0
# neighbourhood              0
# latitude                   0
# longitude                  0
# dtype: int64

# %% [markdown]
# In the 'reviews_per_month','last_review','host_name','name' columns have null values, so for all the missing values, we will just replace it with 0.
#
# We can ignore the null values present in name and host_name columns as we have host_id and property_id for the analysis.

# %%
airbnb_df[['reviews_per_month','last_review']] = airbnb_df[['reviews_per_month','last_review']].fillna(0.0)

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ### **Correlation Heatmap**

# %% [markdown]
# Now we have to plot the heatmap for find the correlation between the data.

# %%
sns.heatmap(airbnb_df.corr(),annot= True)
# Out:
# <ipython-input-18-340c6b288757>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(airbnb_df.corr(),annot= True)
# <Axes: >

# %% [markdown]
# From the above heatmap, we know that there is not a strong correlation between the data except review_per_month and number_of_review.

# %% [markdown]
# ## ***All manipulations have done and insights found***

# %% [markdown]
# *   The 'reviews_per_month','last_review','host_name','name' columns have null
# values, so for all the missing values
# *   We replaced the missing values with 0.
# *   Co-relation between the data was found by heatmap.
# *   There is not a strong correlation between the data except review_per_month and number_of_review was found.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### **Chart - 1**

# %% [markdown]
# ### **4.1. Which hosts are the busiest and why?**

# %%
hosts_areas = airbnb_df.groupby(['host_id','host_name','neighbourhood_group'])['calculated_host_listings_count'].count().reset_index()
new_df1 = hosts_areas.sort_values(by='calculated_host_listings_count', ascending=False).head()
new_df1
# Out:
#          host_id       host_name neighbourhood_group  \
# 34740  219517861    Sonder (NYC)           Manhattan
# 29481  107434423      Blueground           Manhattan
# 19626   30283594            Kara           Manhattan
# 12839   12243051          Sonder           Manhattan
# 14475   16098958  Jeremy & Laura           Manhattan
#
#        calculated_host_listings_count
# 34740                             327
# 29481                             230
# 19626                             121
# 12839                              96
# 14475                              96

# %%
new_df1.plot.bar(x= "host_name", y = "calculated_host_listings_count",figsize=[10,5])
# Out:
# <Axes: xlabel='host_name'>

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
#    Pandas' Groupby operation is a powerful and versatile function in Python. It allows you to split your data into separate groups to perform computations for better analysis.
#
#   To find the solution for this question, we have to Group by "host_id" and "host_name" and count the "host_listing_ count" by using Count method.
#
#    The bar chart, we can see which groups are highest or most common, and how other groups compare against the others.
#
#    From the bar chart , we can find easily which host has the most calculated host listings count.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# From the above analysis, we can observe that the Sonder(NYC) from Manhattan is the busiest host and having maximum number of properties.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth?**
# ##### **Justify with specific reason.**

# %% [markdown]
# The Sonder(NYC) from Manhattan is the busiest host and having maximum number of properties. The top five locations are only in manhattan, so most of the people interested to staying in nearby Manhattan.

# %% [markdown]
# ### **Chart - 2**

# %% [markdown]
# ### **4.2 Find the price range with respective to neighbourhood group (min,max and average price)**
#
# Let’s write the code to get the price range with respect to neighbourhood(min,max, and average)

# %%
# Chart - 2 visualization code
airbnb_df.groupby(['neighbourhood_group'],dropna=True).agg({'price' :['mean', 'min', 'max']})
# Out:
#                           price
#                            mean min    max
# neighbourhood_group
# Bronx                 87.496792   0   2500
# Brooklyn             124.383207   0  10000
# Manhattan            196.875814   0  10000
# Queens                99.517649  10  10000
# Staten Island        114.812332  13   5000

# %% [markdown]
# Here , I grouped the Neighbourhood_group by groupby method and then computed aggregation like mean price ,minimum price, maximum price.

# %%
plt.figure(figsize=(8,6))
plt.scatter(x='neighbourhood_group',y='price',data=airbnb_df)
plt.xlabel('neighbourhood_group')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# A scatter plot identifies a possible relationship between changes observed in different sets of variables.
#
# It provides a visual and statistical means to test the strength of a relationship between two variables.
#
# We plotted the scatter plot between the neighbourhood group and Price.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# From the scatter plot, We can easily identify which neighbourhood group has the most places and also price range. Now we can observe that the maximum number people from manhattan and the highest price also same group.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth?**
# ##### **Justify with specific reason.**

# %% [markdown]
# From the above analysis, we can observe that the maximum number people from manhattan and the highest price also same group. So now we can understand that the price does not affect to visiting people.

# %% [markdown]
# ### **Chart - 3**

# %% [markdown]
# ### **4.3 Find the price range from highest to lowest order**
#
# Let’s answer another question, the price range from highest price to lowest price

# %%
# Chart - 3 visualization code
new_data = [airbnb_df['name'],airbnb_df['host_name'],airbnb_df['neighbourhood_group'],airbnb_df['neighbourhood'],airbnb_df['room_type'],airbnb_df['price']]
new_df2 = pd.concat(new_data, axis=1)
new_df2.sort_values("price",ascending = False)
# Out:
#                                                     name host_name  \
# 9151                 Furnished room in Astoria apartment  Kathrine
# 17692    Luxury 1 bedroom apt. -stunning Manhattan views      Erin
# 29238                                1-BR Lincoln Center    Jelena
# 40433  2br - The Heart of NYC: Manhattans Lower East ...      Matt
# 12342                Quiet, Clean, Lit @ LES & Chinatown       Amy
# ...                                                  ...       ...
# 25778      Modern apartment in the heart of Williamsburg   Aymeric
# 25796       Cozy yet spacious private brownstone bedroom   Adeyemi
# 25433      ★Hostel Style Room | Ideal Traveling Buddies★    Anisha
# 26841  Coliving in Brooklyn! Modern design / Shared room    Sergii
# 25795  Contemporary bedroom in brownstone with nice view   Adeyemi
#
#       neighbourhood_group       neighbourhood        room_type  price
# 9151               Queens             Astoria     Private room  10000
# ...

# %% [markdown]
# Here, I selected only the required column and stored it in a separate Dataframe. Then I sorted the price range from Maximum to Minimum.
# From that, we can find the "Furnished room in Astoria apartment" ,"Luxury 1 bedroom apt. -stunning Manhattan views" and "1-BR Lincoln Center" which are the most expensive.

# %%
new_df2.plot(x="neighbourhood_group",figsize=(9,6))
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# Line graphs are useful in that they show data variables and trends very clearly and can help to make predictions about the results of data not yet recorded.
#
# Here we can easily show the high price to lowt price by plotting line chart.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# From the line plot, we can observe the high price to low price range and also which group and places have the highest price and the lowest price.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth?**
# ##### **Justify with specific reason.**

# %% [markdown]
# From that, we can find the "Furnished room in Astoria apartment" ,"Luxury 1 bedroom apt. -stunning Manhattan views" and "1-BR Lincoln Center" which are the most expensive.

# %% [markdown]
# ### **Chart - 4**

# %% [markdown]
# ### **4.4 How room types occupied by a neighborhood group?**
#
# To answer this question, We groupby the neighbourhood group and Room type and counted the room types after that unstacked the each room type.

# %%
# Chart - 4 visualization code
new_dff = airbnb_df.groupby(['neighbourhood_group','room_type'])['room_type'].count().unstack()
print(new_dff)
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                            379           652           60
# Brooklyn                        9559         10132          413
# Manhattan                      13199          7982          480
# Queens                          2096          3372          198
# Staten Island                    176           188            9

# %%
plt.figure(figsize=(13,7))
plt.title("Room Type on Neighbourhood Group")
sns.countplot(x= airbnb_df.neighbourhood_group,hue=airbnb_df.room_type, palette="muted")
plt.show()

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable. Using the palette we can generate the point with different colors. It is very simple to show number of occurrence of item and is based on certain type of category.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# From that, we can observe that the neighbourhood groups Brooklyn and Manhattan in which room type of private room and Entire home/apt only mostly occupied.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth?**
# ##### **Justify with specific reason.**

# %% [markdown]
# Here we can observe that the Private room and Entire home/apt only mostly occupied in Brooklyn and Manhattan Groups. The Shared room was least occupied of all neighbourhood groups. People are prefer to stay in private room or Entire home/apt only and hey don't want to stay in shared room.

# %% [markdown]
# ### **Chart - 5**

# %% [markdown]
# ### **4.5. Find availablity of room for each neighbourhood group ?**
#
# To see the room availability for Each neighbourhood group plot the boxpot between the neighbourhood_group vs. availablity_365 columns.
#
# Let’s see the boxplot for each type of neighbourhood groups.

# %%
# Chart - 5 visualization code

# %%
plt.style.use('classic')
plt.figure(figsize=(10,5))
plt.title("Neighbourhood Group vs. Availability Room")
sns.boxplot(data=airbnb_df, x='neighbourhood_group',y='availability_365',palette="dark")
plt.show()

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# Box plots are used to show overall patterns of response for a group. They provide a useful way to visualise the range and other characteristics of responses for a large group. It organizes large amounts of data, and visualizes outlier values and well suitable for comparing range and distribution for groups of numerical data.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# From the graph, Its shows the relationship between the availability of room and neighborhood group. Now we can find the average number of days room available in 365 days.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth?**
# ##### **Justify with specific reason.**

# %% [markdown]
# It visualise the range, average and also used to detect outliers for a large groups. From that we can compare easily with other neighborhood group.
#
# The Boxplot indicates the minimum and maximum values, median, quartiles, the symmetry and skewness of the data. The "Staten Island" has the highest number of days available compared to other neighbourhood groups.

# %% [markdown]
# ### **Chart - 6**

# %% [markdown]
# ### **4.6.Find the Top 10 place name based on number of reviews?**
#
# To solve this question, we keep only the required column from the dataframe, sorting the number of reveiws from maximum to minimum.
# Now we plot the line plot between place name vs number of reveiws for better understanding.

# %%
# Chart - 6 visualization code
Keep_column = [airbnb_df["name"],airbnb_df['neighbourhood_group'],airbnb_df["number_of_reviews"]]
new_df2 = pd.concat(Keep_column, axis=1)
top_reveives = new_df2.sort_values(by = "number_of_reviews",ascending = False).head(10)
print(top_reveives)
# Out:
#                                                     name neighbourhood_group  \
# 11759                            Room near JFK Queen Bed              Queens
# 2031                          Great Bedroom in Manhattan           Manhattan
# 2030                      Beautiful Bedroom in Manhattan           Manhattan
# 2015                        Private Bedroom in Manhattan           Manhattan
# 13495                            Room Near JFK Twin Beds              Queens
# 10623                  Steps away from Laguardia airport              Queens
# 1879            Manhattan Lux Loft.Like.Love.Lots.Look !           Manhattan
# 20403  Cozy Room Family Home LGA Airport NO CLEANING FEE              Queens
# 4870                  Private brownstone studio Brooklyn            Brooklyn
# 471                      LG Private Room/Family Friendly            Brooklyn
#
#        number_of_reviews
# 11759                629
# 2031                 607
# 2030                 597
# ...

# %%
x = top_reveives["number_of_reviews"]
y = top_reveives["name"]
plt.plot(x, y)
plt.xlabel("number_of_reviews")
plt.ylabel("name")
plt.title("Top 10 place based on number of reviews ")
plt.show()

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# It is also helpful to show small changes that are difficult to measure in other graphs. It presents a good impression of trends and changes.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# From the above plot, we can get that the place of "Room near JFK Queen Bed" is having maximum number of reveiws.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth?**
# ##### **Justify with specific reason.**

# %% [markdown]
# Now we can observe properties in Queens getting more reviews. From that, we get the information that the room with the lowest price having more number of reviews. Price also playing the role in occupying rooms.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# * Manhattan and Brooklyn are the two distinguished, expensive & posh areas of NY.
#
# * Most visitors don't prefer shared rooms, they tend to visit private room or entire home.
#
# * Although location of property has a lot to do with determining its price, a property in popular location is often unoccupied.
#
# * A property average guest ratings would be great, which would be helpful in understanding the property and could also be a determining in pricing.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. People often prefer only Entire home/ apartments than the private room for the long time stay.
# 2. Manhattan and Brooklyn is the place which got more of properties and also which is the crowded place throughout NY.
# 3. As we can observe properties in Queens got the most reviews.
# 4. Sonder is the busiest host in NY, as he owns several properties in Manhattan (of Entire home/apartment room type).
